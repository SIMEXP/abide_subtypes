# %% [markdown]
# Run the GLM on the Matlab stuff and see what I get

# %%
# Imports
import os
import numpy as np
import pandas as pd
from scipy import io as sio
import statsmodels.api as sm
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
base_path = '/data1/guilimin/abide/subtype/sc7/full_maybe/'
w_tmp = 'sbt_weights_net_{}.csv'

# %%
w_path = '/data1/guilimin/abide/subtype/sc7/srs_maybe/sbt_weights_net_1.csv'
m_path = '/data1/guilimin/abide/pheno/sc7/model_full_maybe_sc7.csv'

# %%
# Model
model = pd.read_csv(m_path)

# %%
# Make one big file
for sbt_id in np.arange(5)+1:
    weights = pd.read_csv(os.path.join(base_path, w_tmp.format(sbt_id)))
    # Give subject column a name
    weights.rename(columns={' ':'SUB_ID'}, inplace=True)
    # Drop whitespace 
    weights.columns = weights.columns.str.strip(' ')
    # Get back to normal names
    weights.SUB_ID = weights.SUB_ID.str.extract('(?<=sub_)(\d+)').astype(int)
    weights[weights.columns[1:]].add_prefix('net{}_'.format(sbt_id))
    model = pd.merge(model, weights, on='SUB_ID', how='inner', )

# %%
sbt_id = 1
weights = pd.read_csv(os.path.join(base_path, w_tmp.format(sbt_id)))
weights.rename(columns={' ':'SUB_ID'}, inplace=True)
weights.columns = weights.columns.str.strip(' ')
weights.SUB_ID = weights.SUB_ID.str.extract('(?<=sub_)(\d+)').astype(int)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:5: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)

# %%
weights.columns
# Out:
# Index(['SUB_ID', 'sub1', 'sub2', 'sub3', 'sub4', 'sub5'], dtype='object')

# %%
merged = pd.merge(model, weights, on='SUB_ID', how='inner')

# %%
net_id = 3
weights = pd.read_csv(os.path.join(base_path, w_tmp.format(net_id)))
weights.rename(columns={' ':'SUB_ID'}, inplace=True)
weights.columns = weights.columns.str.strip(' ')
weights.SUB_ID = weights.SUB_ID.str.extract('(?<=sub_)(\d+)').astype(int)
merged = pd.merge(model, weights, on='SUB_ID', how='inner')

f = plt.figure(figsize=(16,5))
for i in np.arange(5)+1:
    ax = f.add_subplot(1,5,i)
    
    for a, b in merged.groupby('DX_GROUP'):
        y = b['sub{}'.format(i)].values
        x = np.random.normal(a, 0.08, len(y))
        ax.plot(x, y, '.k')
    merged.boxplot('sub{}'.format(i), by='DX_GROUP', ax=ax)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:5: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-3fbc204e18b3> in <module>()
#      14         x = np.random.normal(a, 0.08, len(y))
#      15         ax.plot(x, y, '.k')
# ---> 16     merged.boxplot('sub{}'.format(i), by='DX_GROUP', ax=ax, linewidth=2)
#
# /home/surchs/Venv/serv3/lib/python3.5/site-packages/pandas/core/frame.py in boxplot(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    5579     ax = plots.boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    5580                        grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 5581                        return_type=return_type, **kwds)
#    5582     plt.draw_if_interactive()
#    5583     return ax
#
# /home/surchs/Venv/serv3/lib/python3.5/site-packages/pandas/tools/plotting.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2745                                          by=by, grid=grid, figsize=figsize,
#    2746                                          ax=ax, layout=layout,
# -> 2747                                          return_type=return_type)
#    2748     else:
#    2749         if layout is not None:
#
# /home/surchs/Venv/serv3/lib/python3.5/site-packages/pandas/tools/plotting.py in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#    3153         gp_col = grouped[col]
#    3154         keys, values = zip(*gp_col)
# -> 3155         re_plotf = plotf(keys, values, ax, **kwargs)
#    3156         ax.set_title(col)
#    3157         ax.set_xlabel(pprint_thing(by))
#
# /home/surchs/Venv/serv3/lib/python3.5/site-packages/pandas/tools/plotting.py in plot_group(keys, values, ax)
#    2717         keys = [pprint_thing(x) for x in keys]
#    2718         values = [remove_na(v) for v in values]
# -> 2719         bp = ax.boxplot(values, **kwds)
#    2720         if kwds.get('vert', 1):
#    2721             ax.set_xticklabels(keys, rotation=rot, fontsize=fontsize)
#
# /home/surchs/Venv/serv3/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1810                     warnings.warn(msg % (label_namer, func.__name__),
#    1811                                   RuntimeWarning, stacklevel=2)
# -> 1812             return func(ax, *args, **kwargs)
#    1813         pre_doc = inner.__doc__
#    1814         if pre_doc is None:
#
# TypeError: boxplot() got an unexpected keyword argument 'linewidth'

# %%
weights
# Out:
#          SUB_ID   sub1   sub2   sub3   sub4   sub5
# 0    sub_51459   0.328  0.044 -0.093 -0.208 -0.104
# 1    sub_51465   0.140 -0.195  0.061 -0.037  0.035
# 2    sub_51467  -0.108 -0.033  0.065 -0.064  0.156
# 3    sub_51473  -0.115  0.036  0.136  0.032 -0.049
# 4    sub_51474  -0.246 -0.013  0.010  0.176  0.084
# 5    sub_51484  -0.028  0.148  0.090 -0.103 -0.079
# 6    sub_51485  -0.143  0.045 -0.102  0.165  0.017
# 7    sub_51486   0.200 -0.073 -0.146  0.039 -0.063
# 8    sub_51487   0.007 -0.188  0.192 -0.049  0.077
# 9    sub_51488  -0.145  0.218 -0.114  0.053 -0.028
# 10   sub_50772   0.067  0.171 -0.268 -0.025 -0.009
# 11   sub_50774  -0.270 -0.273 -0.010  0.052  0.490
# 12   sub_50776  -0.210 -0.078 -0.040  0.079  0.240
# 13   sub_50777  -0.016 -0.022 -0.256  0.319 -0.084
# 14   sub_50779  -0.118 -0.185  0.109 -0.030  0.244
# 15   sub_50782   0.107  0.301 -0.151  0.026 -0.308
# 16   sub_50785   0.197  0.285  0.041 -0.089 -0.415
# 17   sub_50786  -0.077 -0.165  0.216  0.065  0.013
# 18   sub_50787   0.304 -0.031 -0.084 -0.054 -0.165
# 19   sub_50789  -0.193 -0.317  0.292 -0.030  0.310
# 20   sub_50791  -0.141  0.098 -0.336  0.279  0.028
# 21   sub_50793  -0.087 -0.183  0.041 -0.050  0.281
# 22   sub_50794  -0.205 -0.148 -0.093  0.126  0.294
# 23   sub_50797   0.523  0.029 -0.018 -0.268 -0.285
# 24   sub_50799   0.026  0.289 -0.013 -0.056 -0.237
# 25   sub_50800   0.111  0.079  0.061 -0.087 -0.149
# 26   sub_50801  -0.233 -0.360  0.228  0.059  0.352
# 27   sub_50802  -0.142 -0.158  0.018  0.082  0.201
# 28   sub_50803   0.307  0.029  0.112 -0.282 -0.147
# 29   sub_50804   0.191  0.201  0.025 -0.098 -0.308
# ..          ...    ...    ...    ...    ...    ...
# 538  sub_50559   0.083 -0.096  0.120 -0.084 -0.000
# 539  sub_50560  -0.080 -0.036  0.250 -0.030 -0.040
# 540  sub_50561   0.154 -0.067  0.120 -0.053 -0.129
# 541  sub_50562   0.057 -0.029  0.012  0.054 -0.092
# 542  sub_50564  -0.193 -0.129 -0.069  0.098  0.274
# 543  sub_50567  -0.125 -0.165 -0.053  0.339 -0.006
# 544  sub_50568   0.058 -0.030  0.073 -0.104  0.016
# 545  sub_50570  -0.104  0.135  0.028 -0.056  0.011
# 546  sub_50571   0.011 -0.115  0.334 -0.134 -0.018
# 547  sub_50573  -0.150  0.089  0.011 -0.132  0.188
# 548  sub_50574   0.155  0.067  0.079 -0.078 -0.203
# 549  sub_50575   0.113  0.067 -0.041 -0.144 -0.008
# 550  sub_50577  -0.038  0.221 -0.146 -0.022 -0.042
# 551  sub_50578   0.108 -0.109  0.015  0.066 -0.081
# 552  sub_50601   0.043 -0.081 -0.114 -0.018  0.135
# 553  sub_50602   0.083 -0.143 -0.006  0.104 -0.045
# 554  sub_50603  -0.139 -0.198 -0.072  0.171  0.217
# 555  sub_50606   0.150  0.009 -0.088  0.071 -0.164
# 556  sub_50607   0.038  0.367  0.016 -0.058 -0.343
# 557  sub_50608  -0.009  0.190 -0.046  0.025 -0.162
# 558  sub_50609   0.038  0.232  0.056 -0.136 -0.168
# 559  sub_50611  -0.063  0.317 -0.163 -0.042 -0.076
# 560  sub_50612  -0.170 -0.058 -0.061  0.110  0.165
# 561  sub_50614   0.008 -0.089 -0.043 -0.035  0.142
# 562  sub_50616   0.123 -0.208 -0.026 -0.104  0.193
# 563  sub_50617  -0.014  0.359 -0.111 -0.124 -0.126
# 564  sub_50618   0.102  0.071  0.082  0.072 -0.301
# 565  sub_50622  -0.144  0.010 -0.038  0.119  0.049
# 566  sub_50626   0.202  0.133 -0.144 -0.283  0.050
# 567  sub_50628  -0.133 -0.358  0.100  0.382  0.031
#
# [568 rows x 6 columns]
